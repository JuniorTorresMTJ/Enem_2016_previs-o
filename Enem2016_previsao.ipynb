# %% [markdown]
# <a href="https://colab.research.google.com/github/JuniorTorresMTJ/Enem_2016_previsao/blob/master/Enem2016_previsao.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Criar um modelo para prever a nota da prova de matemática de quem participou do ENEM 2016.

# %%
import pandas as pd
url="https://github.com/JuniorTorresMTJ/Enem_2016_previs-o/blob/master/test.csv?raw=true"

# %%
dados=pd.read_csv(url)
dados.head()
# Out:
#                                NU_INSCRICAO  CO_UF_RESIDENCIA  ... Q027  Q047
# 0  73ff9fcc02f0a99919906c942c2e1a1042cdcf98                41  ...    C     A
# 1  71a95f9f1b91a82c65ad94abbdf9f54e6066f968                21  ...    F     A
# 2  b38a03232f43b11c9d0788abaf060f7366053b6d                23  ...  NaN     A
# 3  70b682d9a3636be23f6120fa9d6b164eb3c6002d                15  ...  NaN     A
# 4  715494628a50142ce8cb17191cfe6d0f3cae0934                41  ...  NaN     A
#
# [5 rows x 47 columns]

# %% [markdown]
# Para conhecer melhor o csv vou printar todas as colunas

# %%
print(dados.columns.values)
# Out:
# ['NU_INSCRICAO' 'CO_UF_RESIDENCIA' 'SG_UF_RESIDENCIA' 'NU_IDADE' 'TP_SEXO'
#  'TP_COR_RACA' 'TP_NACIONALIDADE' 'TP_ST_CONCLUSAO' 'TP_ANO_CONCLUIU'
#  'TP_ESCOLA' 'TP_ENSINO' 'IN_TREINEIRO' 'TP_DEPENDENCIA_ADM_ESC'
#  'IN_BAIXA_VISAO' 'IN_CEGUEIRA' 'IN_SURDEZ' 'IN_DISLEXIA' 'IN_DISCALCULIA'
#  'IN_SABATISTA' 'IN_GESTANTE' 'IN_IDOSO' 'TP_PRESENCA_CN' 'TP_PRESENCA_CH'
#  'TP_PRESENCA_LC' 'CO_PROVA_CN' 'CO_PROVA_CH' 'CO_PROVA_LC' 'CO_PROVA_MT'
#  'NU_NOTA_CN' 'NU_NOTA_CH' 'NU_NOTA_LC' 'TP_LINGUA' 'TP_STATUS_REDACAO'
#  'NU_NOTA_COMP1' 'NU_NOTA_COMP2' 'NU_NOTA_COMP3' 'NU_NOTA_COMP4'
#  'NU_NOTA_COMP5' 'NU_NOTA_REDACAO' 'Q001' 'Q002' 'Q006' 'Q024' 'Q025'
#  'Q026' 'Q027' 'Q047']

# %%
colunas_notas = ['NU_NOTA_CN','NU_NOTA_CH','NU_NOTA_LC','NU_NOTA_REDACAO']
dados_notas = dados[colunas_notas].dropna()
dados_notas.columns = ['natureza','humanas','portugues','redação']
dados_notas.head()
# Out:
#    natureza  humanas  portugues  redação
# 0     464.8    443.5      431.8    420.0
# 1     391.1    491.1      548.0    580.0
# 2     595.9    622.7      613.6    320.0
# 4     592.9    492.6      571.4    320.0
# 5     414.5    568.5      542.5    560.0

# %%
dados_notas.describe()
# Out:
#           natureza      humanas    portugues      redação
# count  3360.000000  3360.000000  3360.000000  3360.000000
# mean    473.500655   529.748720   514.618631   528.065476
# std      70.678178    72.747219    67.118345   151.491764
# min       0.000000   330.600000     0.000000     0.000000
# 25%     419.775000   480.000000   468.700000   440.000000
# 50%     458.450000   532.400000   517.300000   540.000000
# 75%     514.500000   579.800000   562.400000   600.000000
# max     778.900000   773.600000   708.900000   980.000000

# %%
cor = dados_notas.corr()
cor
# Out:
#            natureza   humanas  portugues   redação
# natureza   1.000000  0.596123   0.545801  0.442692
# humanas    0.596123  1.000000   0.679993  0.537141
# portugues  0.545801  0.679993   1.000000  0.491590
# redação    0.442692  0.537141   0.491590  1.000000

# %%
import seaborn as sns
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
sns.heatmap(cor)

# %%
sns.pairplot(dados_notas);
